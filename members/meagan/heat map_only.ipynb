# %%
#dependencies
import pandas as pd
import requests
import geopandas as gpd
import seaborn as sns
sns.set(style="darkgrid")
import json
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
import gmaps

# %%
pip install geopandas
# Out:
# Collecting geopandas
#   Downloading geopandas-0.9.0-py2.py3-none-any.whl (994 kB)
#      |████████████████████████████████| 994 kB 1.4 MB/s eta 0:00:01
# Collecting pyproj>=2.2.0
#   Downloading pyproj-3.1.0-cp37-cp37m-macosx_10_9_x86_64.whl (7.6 MB)
#      |████████████████████████████████| 7.6 MB 6.7 MB/s eta 0:00:01
# Collecting fiona>=1.8
#   Downloading Fiona-1.8.20-cp37-cp37m-macosx_10_9_x86_64.whl (19.3 MB)
#      |████████████████████████████████| 19.3 MB 12.3 MB/s eta 0:00:01
# Collecting shapely>=1.6
#   Downloading Shapely-1.7.1-cp37-cp37m-macosx_10_9_x86_64.whl (1.0 MB)
#      |████████████████████████████████| 1.0 MB 6.4 MB/s eta 0:00:01
# Requirement already satisfied: pandas>=0.24.0 in /Users/meaganmb_11/opt/anaconda3/lib/python3.7/site-packages (from geopandas) (1.0.1)
# Requirement already satisfied: certifi in /Users/meaganmb_11/opt/anaconda3/lib/python3.7/site-packages (from pyproj>=2.2.0->geopandas) (2019.11.28)
# Requirement already satisfied: setuptools in /Users/meaganmb_11/opt/anaconda3/lib/python3.7/site-packages (from fiona>=1.8->geopandas) (46.0.0.post20200309)
# Collecting click-plugins>=1.0
#   Downloading click_plugins-1.1.1-py2.py3-none-any.whl (7.5 kB)
# Requirement already satisfied: six>=1.7 in /Users/meaganmb_11/opt/anaconda3/lib/python3.7/site-packages (from fiona>=1.8->geopandas) (1.14.0)
# Collecting munch
#   Downloading munch-2.5.0-py2.py3-none-any.whl (10 kB)
# Requirement already satisfied: click>=4.0 in /Users/meaganmb_11/opt/anaconda3/lib/python3.7/site-packages (from fiona>=1.8->geopandas) (7.0)
# Collecting cligj>=0.5
#   Downloading cligj-0.7.2-py3-none-any.whl (7.1 kB)
# Requirement already satisfied: attrs>=17 in /Users/meaganmb_11/opt/anaconda3/lib/python3.7/site-packages (from fiona>=1.8->geopandas) (19.3.0)
# Requirement already satisfied: numpy>=1.13.3 in /Users/meaganmb_11/opt/anaconda3/lib/python3.7/site-packages (from pandas>=0.24.0->geopandas) (1.18.1)
# Requirement already satisfied: pytz>=2017.2 in /Users/meaganmb_11/opt/anaconda3/lib/python3.7/site-packages (from pandas>=0.24.0->geopandas) (2019.3)
# Requirement already satisfied: python-dateutil>=2.6.1 in /Users/meaganmb_11/opt/anaconda3/lib/python3.7/site-packages (from pandas>=0.24.0->geopandas) (2.8.1)
# Installing collected packages: pyproj, click-plugins, munch, cligj, fiona, shapely, geopandas
# Successfully installed click-plugins-1.1.1 cligj-0.7.2 fiona-1.8.20 geopandas-0.9.0 munch-2.5.0 pyproj-3.1.0 shapely-1.7.1
# Note: you may need to restart the kernel to use updated packages.

# %%
file_path = '../../Resources/crime_data.csv'
file = pd.read_csv(file_path)

data = [file['Date Rptd'], file['DATE OCC'], file['TIME OCC'], file['AREA NAME'], file['Crm Cd Desc'], 
       file['Vict Age'],file['Vict Sex'], file['Vict Descent'], file['Premis Desc'], file['Weapon Desc'], 
       file['LOCATION'], file['LAT'], file['LON']]
df = pd.DataFrame(data)
df = df.transpose()
# df.head()

# %%
# Path to csv file
file_one = "../../Resources/2019_crime_data.csv"

# Read csv file
crime2019_df = pd.read_csv(file_one)

# Display head of csv file
crime2019_df.head()
# Out:
#        DR_NO       Date Rptd        DATE OCC  TIME OCC  AREA     AREA NAME  \
# 0  190805874  2/12/2019 0:00  2/12/2019 0:00      1900      8      West LA
# 1  191213477  5/12/2019 0:00  5/12/2019 0:00       200     12  77th Street
# 2  190409679  5/10/2019 0:00  5/10/2019 0:00       330      4   Hollenbeck
# 3  191510263   5/1/2019 0:00  4/30/2019 0:00      1610     15  N Hollywood
# 4  190320119  8/30/2019 0:00  8/30/2019 0:00      1815      3    Southwest
#
#    Rpt Dist No  Crm Cd                                        Crm Cd Desc  \
# 0          857     310                                           BURGLARY
# 1         1203     740  VANDALISM - FELONY ($400 & OVER, ALL CHURCH VA...
# 2          489     745           VANDALISM - MISDEAMEANOR ($399 OR UNDER)
# 3         1599     624                           BATTERY - SIMPLE ASSAULT
# 4          354     930             CRIMINAL THREATS - NO WEAPON DISPLAYED
#
#    Vict Age  ... Vict Descent               Premis Desc Weapon Used Cd  \
# 0        34  ...            P    SINGLE FAMILY DWELLING            NaN
# 1        24  ...            H  VEHICLE, PASSENGER/TRUCK            NaN
# 2        24  ...            H               PARKING LOT          304.0
# 3        53  ...            O    SINGLE FAMILY DWELLING          400.0
# 4        49  ...            B    SINGLE FAMILY DWELLING          511.0
#
#                                       Weapon Desc Status  Status Desc  \
# 0                                             NaN     IC  Invest Cont
# 1                                             NaN     IC  Invest Cont
# 2                                        CLUB/BAT     IC  Invest Cont
# 3  STRONG-ARM (HANDS, FIST, FEET OR BODILY FORCE)     IC  Invest Cont
# 4                                   VERBAL THREAT     IC  Invest Cont
#
#                                   LOCATION Cross Street      LAT       LON
# 0  1500    BEVERWIL                     DR          NaN  34.0524 -118.3986
# 1  1700 W  45TH                         ST          NaN  34.0028 -118.3089
# 2  1300 S  SOTO                         ST          NaN  34.0263 -118.2196
# 3  2800    MONTCALM                     AV          NaN  34.1223 -118.3563
# 4  2700    OBAMA                        BL          NaN  34.0222 -118.3227
#
# [5 rows x 21 columns]

# %%
# new_crime2019_df = crime2019_df.loc[(crime2019_df["Vict Age"] > 0,:)
new_crime = crime2019_df[crime2019_df["Vict Age"] != -1]
# age= new_crime2019_df["Vict Age"].value_counts()
new_crime_2019 = new_crime[new_crime["Vict Age"] != -2]
# age = new_crime_2019["Vict Age"].value_counts()
# age

# %%
# Add One Name column
new_crime_2019["One"]= 1
# Out:
# /Users/meaganmb_11/opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %%
# Configure gmaps
gmaps.configure(api_key = "AIzaSyAt_EOD_wTikFHLRpiIbXXHi6TAUCduZAg")

# %%
# Store 'Lat' and 'Lng' into  locations 
locations = new_crime_2019[["LAT", "LON"]].astype(float)

# Convert Humidity Rate to float and store
one = new_crime_2019['One'].astype(float)

# %%
# Create a humidity Heatmap layer
fig = gmaps.figure()

heat_layer = gmaps.heatmap_layer(locations, weights=one, 
                                 dissipating=False, max_intensity=1,
                                 point_radius = 0.0005)

fig.add_layer(heat_layer)

fig
# Out:
# Figure(layout=FigureLayout(height='420px'))

# %%
nb = '../../Resources/la-county-neighborhoods-current/l.a. county neighborhood (current).shp'
regions = gpd.read_file(nb)

regions.sample(5)
# Out:
#                       slug                                  set  \
# 5             alondra-park  L.A. County Neighborhoods (Current)
# 126              larchmont  L.A. County Neighborhoods (Current)
# 109               industry  L.A. County Neighborhoods (Current)
# 246                vincent  L.A. County Neighborhoods (Current)
# 115  la-crescenta-montrose  L.A. County Neighborhoods (Current)
#
#                                    kind             external_i  \
# 5    L.A. County Neighborhood (Current)           alondra-park
# 126  L.A. County Neighborhood (Current)              larchmont
# 109  L.A. County Neighborhood (Current)               industry
# 246  L.A. County Neighborhood (Current)                vincent
# 115  L.A. County Neighborhood (Current)  la-crescenta-montrose
#
#                       name                                         display_na  \
# 5             Alondra Park    Alondra Park L.A. County Neighborhood (Current)
# 126              Larchmont       Larchmont L.A. County Neighborhood (Current)
# 109               Industry        Industry L.A. County Neighborhood (Current)
# 246                Vincent         Vincent L.A. County Neighborhood (Current)
# 115  La Crescenta-Montrose  La Crescenta-Montrose L.A. County Neighborhood...
#
#                sqmi                 type name_1 slug_1  \
# 5     1.13989423058  unincorporated-area   None   None
# 126  0.486332164533    segment-of-a-city   None   None
# 109   12.3503569476      standalone-city   None   None
# 246   1.47902846141  unincorporated-area   None   None
# 115   3.42644417184  unincorporated-area   None   None
#
#                                               geometry
# 5    POLYGON ((-118.32651 33.89757, -118.32649 33.8...
# 126  POLYGON ((-118.31261 34.08361, -118.30931 34.0...
# 109  MULTIPOLYGON (((-117.88393 33.99597, -117.8839...
# 246  POLYGON ((-117.91883 34.11430, -117.91680 34.1...
# 115  POLYGON ((-118.23692 34.25212, -118.22161 34.2...

# %%
# regions['l.a. county neighborhood (current)'] = regions['set'].str.replace(' \(.+\)', '').str.lower()

# %%
regions.plot(figsize=(20,20))
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-c8b015d76c08> in <module>
# ----> 1 regions.plot(figsize=(20,20))
#       2 plt.show()
#
# NameError: name 'regions' is not defined

# %% [markdown]
# # Try another appraoch

# %%
new_crime_2019.head()
# Out:
#        DR_NO       Date Rptd        DATE OCC  TIME OCC  AREA     AREA NAME  \
# 0  190805874  2/12/2019 0:00  2/12/2019 0:00      1900      8      West LA
# 1  191213477  5/12/2019 0:00  5/12/2019 0:00       200     12  77th Street
# 2  190409679  5/10/2019 0:00  5/10/2019 0:00       330      4   Hollenbeck
# 3  191510263   5/1/2019 0:00  4/30/2019 0:00      1610     15  N Hollywood
# 4  190320119  8/30/2019 0:00  8/30/2019 0:00      1815      3    Southwest
#
#    Rpt Dist No  Crm Cd                                        Crm Cd Desc  \
# 0          857     310                                           BURGLARY
# 1         1203     740  VANDALISM - FELONY ($400 & OVER, ALL CHURCH VA...
# 2          489     745           VANDALISM - MISDEAMEANOR ($399 OR UNDER)
# 3         1599     624                           BATTERY - SIMPLE ASSAULT
# 4          354     930             CRIMINAL THREATS - NO WEAPON DISPLAYED
#
#    Vict Age  ... Vict Descent               Premis Desc Weapon Used Cd  \
# 0        34  ...            P    SINGLE FAMILY DWELLING            NaN
# 1        24  ...            H  VEHICLE, PASSENGER/TRUCK            NaN
# 2        24  ...            H               PARKING LOT          304.0
# 3        53  ...            O    SINGLE FAMILY DWELLING          400.0
# 4        49  ...            B    SINGLE FAMILY DWELLING          511.0
#
#                                       Weapon Desc Status  Status Desc  \
# 0                                             NaN     IC  Invest Cont
# 1                                             NaN     IC  Invest Cont
# 2                                        CLUB/BAT     IC  Invest Cont
# 3  STRONG-ARM (HANDS, FIST, FEET OR BODILY FORCE)     IC  Invest Cont
# 4                                   VERBAL THREAT     IC  Invest Cont
#
#                                   LOCATION Cross Street      LAT       LON
# 0  1500    BEVERWIL                     DR          NaN  34.0524 -118.3986
# 1  1700 W  45TH                         ST          NaN  34.0028 -118.3089
# 2  1300 S  SOTO                         ST          NaN  34.0263 -118.2196
# 3  2800    MONTCALM                     AV          NaN  34.1223 -118.3563
# 4  2700    OBAMA                        BL          NaN  34.0222 -118.3227
#
# [5 rows x 21 columns]

# %%
area = new_crime_2019["AREA NAME"].value_counts()
area
# Out:
# 77th Street    14174
# Central        13561
# Southwest      13468
# Pacific        12230
# Southeast      11700
# Hollywood      11138
# N Hollywood    11070
# Newton         10720
# Wilshire       10409
# Olympic        10199
# Topanga         9638
# Northeast       9629
# Van Nuys        9549
# Rampart         9500
# West LA         9214
# Mission         9117
# Devonshire      8961
# Harbor          8677
# West Valley     8651
# Hollenbeck      8339
# Foothill        7579
# Name: AREA NAME, dtype: int64

# %%
unique_areas = new_crime_2019.drop_duplicates(subset=["AREA NAME"])
unique_areas
# Out:
#          DR_NO        Date Rptd         DATE OCC  TIME OCC  AREA   \
# 0    190805874   2/12/2019 0:00   2/12/2019 0:00      1900      8
# 1    191213477   5/12/2019 0:00   5/12/2019 0:00       200     12
# 2    190409679   5/10/2019 0:00   5/10/2019 0:00       330      4
# 3    191510263    5/1/2019 0:00   4/30/2019 0:00      1610     15
# 4    190320119   8/30/2019 0:00   8/30/2019 0:00      1815      3
# 6    190623975  12/19/2019 0:00  12/16/2019 0:00       340      6
# 9    191905967   2/13/2019 0:00   2/13/2019 0:00       415     19
# 10   191009883   5/17/2019 0:00   5/17/2019 0:00      1140     10
# 11   191113963   7/22/2019 0:00   7/22/2019 0:00      1955     11
# 14   191818187   8/20/2019 0:00   8/18/2019 0:00      1315     18
# 15   191712393    7/4/2019 0:00   6/26/2019 0:00      1200     17
# 16   192008659    4/3/2019 0:00   3/30/2019 0:00      1700     20
# 18   190220768  10/28/2019 0:00  10/24/2019 0:00      2200      2
# 23   190500813    7/3/2019 0:00    7/3/2019 0:00      1830      5
# 27   191422347  10/21/2019 0:00  10/21/2019 0:00       300     14
# 29   190910164    5/1/2019 0:00   4/29/2019 0:00      1525      9
# 32   191610489   6/19/2019 0:00   6/19/2019 0:00       100     16
# 33   191313738   6/22/2019 0:00   6/22/2019 0:00        30     13
# 37   190712112   6/13/2019 0:00   5/30/2019 0:00      2300      7
# 40   190124292   10/3/2019 0:00   9/28/2019 0:00      1820      1
# 110  192110628   5/27/2019 0:00   5/25/2019 0:00      1200     21
#
#        AREA NAME  Rpt Dist No  Crm Cd  \
# 0        West LA          857     310
# 1    77th Street         1203     740
# 2     Hollenbeck          489     745
# 3    N Hollywood         1599     624
# 4      Southwest          354     930
# 6      Hollywood          645     745
# 9        Mission         1998     510
# 10   West Valley         1028     330
# 11     Northeast         1149     901
# 14     Southeast         1822     440
# 15    Devonshire         1705     946
# 16       Olympic         2016     310
# 18       Rampart          239     330
# 23        Harbor          521     626
# 27       Pacific         1413     210
# 29      Van Nuys          941     813
# 32      Foothill         1602     420
# 33        Newton         1317     330
# 37      Wilshire          769     745
# 40       Central          176     330
# 110      Topanga         2128     330
#
#                                            Crm Cd Desc  Vict Age  ...  \
# 0                                             BURGLARY        34  ...
# 1    VANDALISM - FELONY ($400 & OVER, ALL CHURCH VA...        24  ...
# 2             VANDALISM - MISDEAMEANOR ($399 OR UNDER)        24  ...
# 3                             BATTERY - SIMPLE ASSAULT        53  ...
# 4               CRIMINAL THREATS - NO WEAPON DISPLAYED        49  ...
# 6             VANDALISM - MISDEAMEANOR ($399 OR UNDER)        28  ...
# 9                                     VEHICLE - STOLEN         0  ...
# 10                               BURGLARY FROM VEHICLE        36  ...
# 11                      VIOLATION OF RESTRAINING ORDER        38  ...
# 14                  THEFT PLAIN - PETTY ($950 & UNDER)        51  ...
# 15                           OTHER MISCELLANEOUS CRIME        47  ...
# 16                                            BURGLARY        22  ...
# 18                               BURGLARY FROM VEHICLE        21  ...
# 23                   INTIMATE PARTNER - SIMPLE ASSAULT        45  ...
# 27                                             ROBBERY        32  ...
# 29                      CHILD ANNOYING (17YRS & UNDER)        13  ...
# 32     THEFT FROM MOTOR VEHICLE - PETTY ($950 & UNDER)         0  ...
# 33                               BURGLARY FROM VEHICLE        31  ...
# 37            VANDALISM - MISDEAMEANOR ($399 OR UNDER)        51  ...
# 40                               BURGLARY FROM VEHICLE        33  ...
# 110                              BURGLARY FROM VEHICLE         0  ...
#
#     Vict Descent                                   Premis Desc Weapon Used Cd  \
# 0              P                        SINGLE FAMILY DWELLING            NaN
# 1              H                      VEHICLE, PASSENGER/TRUCK            NaN
# 2              H                                   PARKING LOT          304.0
# 3              O                        SINGLE FAMILY DWELLING          400.0
# 4              B                        SINGLE FAMILY DWELLING          511.0
# 6              H                         CONDOMINIUM/TOWNHOUSE            NaN
# 9            NaN                                        STREET            NaN
# 10             H                                   PARKING LOT            NaN
# 11             H                        SINGLE FAMILY DWELLING            NaN
# 14             O                                        STREET            NaN
# 15             O                        SINGLE FAMILY DWELLING            NaN
# 16             H  MULTI-UNIT DWELLING (APARTMENT, DUPLEX, ETC)            NaN
# 18             W                      VEHICLE, PASSENGER/TRUCK            NaN
# 23             B  MULTI-UNIT DWELLING (APARTMENT, DUPLEX, ETC)          400.0
# 27             W                                        STREET          511.0
# 29             H                                      SIDEWALK            NaN
# 32           NaN                                      DRIVEWAY            NaN
# 33             W                                        STREET            NaN
# 37             H                                        STREET            NaN
# 40             W                                   PARKING LOT            NaN
# 110            O                                        STREET            NaN
#
#                                         Weapon Desc Status   Status Desc  \
# 0                                               NaN     IC   Invest Cont
# 1                                               NaN     IC   Invest Cont
# 2                                          CLUB/BAT     IC   Invest Cont
# 3    STRONG-ARM (HANDS, FIST, FEET OR BODILY FORCE)     IC   Invest Cont
# 4                                     VERBAL THREAT     IC   Invest Cont
# 6                                               NaN     IC   Invest Cont
# 9                                               NaN     IC   Invest Cont
# 10                                              NaN     IC   Invest Cont
# 11                                              NaN     AO   Adult Other
# 14                                              NaN     IC   Invest Cont
# 15                                              NaN     AO   Adult Other
# 16                                              NaN     IC   Invest Cont
# 18                                              NaN     IC   Invest Cont
# 23   STRONG-ARM (HANDS, FIST, FEET OR BODILY FORCE)     AA  Adult Arrest
# 27                                    VERBAL THREAT     AO   Adult Other
# 29                                              NaN     IC   Invest Cont
# 32                                              NaN     IC   Invest Cont
# 33                                              NaN     IC   Invest Cont
# 37                                              NaN     IC   Invest Cont
# 40                                              NaN     IC   Invest Cont
# 110                                             NaN     IC   Invest Cont
#
#                                      LOCATION  \
# 0     1500    BEVERWIL                     DR
# 1     1700 W  45TH                         ST
# 2     1300 S  SOTO                         ST
# 3     2800    MONTCALM                     AV
# 4     2700    OBAMA                        BL
# 6     1300 N  SYCAMORE                     AV
# 9     8000    BROADLEAF                    AV
# 10   16800    VANOWEN                      ST
# 11    5300    MARMION                      WY
# 14            104TH                        ST
# 15   13100    COURBET                      LN
# 16     200 S  NORMANDIE                    AV
# 18     100 N  BEAUDRY                      AV
# 23     700    FIGUEROA                     PL
# 27            SUNSET                       AV
# 29            MARTHA                       ST
# 32   12700    DAVENTRY                     ST
# 33    1700 E  16TH                         ST
# 37    1500    2ND                          AV
# 40     800    SANTEE                       ST
# 110   7600    OSO                          AV
#
#                         Cross Street      LAT       LON
# 0                                NaN  34.0524 -118.3986
# 1                                NaN  34.0028 -118.3089
# 2                                NaN  34.0263 -118.2196
# 3                                NaN  34.1223 -118.3563
# 4                                NaN  34.0222 -118.3227
# 6                                NaN  34.0944 -118.3428
# 9                                NaN  34.2164 -118.4381
# 10                               NaN  34.1939 -118.4989
# 11                               NaN  34.1080 -118.1990
# 14                          FIGUEROA  33.9419 -118.2826
# 15                               NaN  34.3074 -118.5053
# 16                               NaN  34.0712 -118.3004
# 18                               NaN  34.0591 -118.2542
# 23                               NaN  33.7781 -118.2808
# 27   3RD                          AV  33.9960 -118.4735
# 29   KESTER                       AV  34.1731 -118.4574
# 32                               NaN  34.2850 -118.4090
# 33                               NaN  34.0233 -118.2424
# 37                               NaN  34.0455 -118.3189
# 40                               NaN  34.0413 -118.2517
# 110                              NaN  34.2083 -118.5754
#
# [21 rows x 21 columns]

# %%
# Add One Name column
unique_areas["Cases per area"]= [9214, 141714, 8339, 11070, 13468, 11138, 9117, 8651, 9629, 11700, 8961, 10199, 9500, 8677, 12230, 9549, 7579, 10720, 10409, 13561, 9638]
unique_areas
# Out:
# /Users/meaganmb_11/opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#          DR_NO        Date Rptd         DATE OCC  TIME OCC  AREA   \
# 0    190805874   2/12/2019 0:00   2/12/2019 0:00      1900      8
# 1    191213477   5/12/2019 0:00   5/12/2019 0:00       200     12
# 2    190409679   5/10/2019 0:00   5/10/2019 0:00       330      4
# 3    191510263    5/1/2019 0:00   4/30/2019 0:00      1610     15
# 4    190320119   8/30/2019 0:00   8/30/2019 0:00      1815      3
# 6    190623975  12/19/2019 0:00  12/16/2019 0:00       340      6
# 9    191905967   2/13/2019 0:00   2/13/2019 0:00       415     19
# 10   191009883   5/17/2019 0:00   5/17/2019 0:00      1140     10
# 11   191113963   7/22/2019 0:00   7/22/2019 0:00      1955     11
# 14   191818187   8/20/2019 0:00   8/18/2019 0:00      1315     18
# 15   191712393    7/4/2019 0:00   6/26/2019 0:00      1200     17
# 16   192008659    4/3/2019 0:00   3/30/2019 0:00      1700     20
# 18   190220768  10/28/2019 0:00  10/24/2019 0:00      2200      2
# 23   190500813    7/3/2019 0:00    7/3/2019 0:00      1830      5
# 27   191422347  10/21/2019 0:00  10/21/2019 0:00       300     14
# 29   190910164    5/1/2019 0:00   4/29/2019 0:00      1525      9
# 32   191610489   6/19/2019 0:00   6/19/2019 0:00       100     16
# 33   191313738   6/22/2019 0:00   6/22/2019 0:00        30     13
# 37   190712112   6/13/2019 0:00   5/30/2019 0:00      2300      7
# 40   190124292   10/3/2019 0:00   9/28/2019 0:00      1820      1
# 110  192110628   5/27/2019 0:00   5/25/2019 0:00      1200     21
#
#        AREA NAME  Rpt Dist No  Crm Cd  \
# 0        West LA          857     310
# 1    77th Street         1203     740
# 2     Hollenbeck          489     745
# 3    N Hollywood         1599     624
# 4      Southwest          354     930
# 6      Hollywood          645     745
# 9        Mission         1998     510
# 10   West Valley         1028     330
# 11     Northeast         1149     901
# 14     Southeast         1822     440
# 15    Devonshire         1705     946
# 16       Olympic         2016     310
# 18       Rampart          239     330
# 23        Harbor          521     626
# 27       Pacific         1413     210
# 29      Van Nuys          941     813
# 32      Foothill         1602     420
# 33        Newton         1317     330
# 37      Wilshire          769     745
# 40       Central          176     330
# 110      Topanga         2128     330
#
#                                            Crm Cd Desc  Vict Age  ...  \
# 0                                             BURGLARY        34  ...
# 1    VANDALISM - FELONY ($400 & OVER, ALL CHURCH VA...        24  ...
# 2             VANDALISM - MISDEAMEANOR ($399 OR UNDER)        24  ...
# 3                             BATTERY - SIMPLE ASSAULT        53  ...
# 4               CRIMINAL THREATS - NO WEAPON DISPLAYED        49  ...
# 6             VANDALISM - MISDEAMEANOR ($399 OR UNDER)        28  ...
# 9                                     VEHICLE - STOLEN         0  ...
# 10                               BURGLARY FROM VEHICLE        36  ...
# 11                      VIOLATION OF RESTRAINING ORDER        38  ...
# 14                  THEFT PLAIN - PETTY ($950 & UNDER)        51  ...
# 15                           OTHER MISCELLANEOUS CRIME        47  ...
# 16                                            BURGLARY        22  ...
# 18                               BURGLARY FROM VEHICLE        21  ...
# 23                   INTIMATE PARTNER - SIMPLE ASSAULT        45  ...
# 27                                             ROBBERY        32  ...
# 29                      CHILD ANNOYING (17YRS & UNDER)        13  ...
# 32     THEFT FROM MOTOR VEHICLE - PETTY ($950 & UNDER)         0  ...
# 33                               BURGLARY FROM VEHICLE        31  ...
# 37            VANDALISM - MISDEAMEANOR ($399 OR UNDER)        51  ...
# 40                               BURGLARY FROM VEHICLE        33  ...
# 110                              BURGLARY FROM VEHICLE         0  ...
#
#                                       Premis Desc Weapon Used Cd  \
# 0                          SINGLE FAMILY DWELLING            NaN
# 1                        VEHICLE, PASSENGER/TRUCK            NaN
# 2                                     PARKING LOT          304.0
# 3                          SINGLE FAMILY DWELLING          400.0
# 4                          SINGLE FAMILY DWELLING          511.0
# 6                           CONDOMINIUM/TOWNHOUSE            NaN
# 9                                          STREET            NaN
# 10                                    PARKING LOT            NaN
# 11                         SINGLE FAMILY DWELLING            NaN
# 14                                         STREET            NaN
# 15                         SINGLE FAMILY DWELLING            NaN
# 16   MULTI-UNIT DWELLING (APARTMENT, DUPLEX, ETC)            NaN
# 18                       VEHICLE, PASSENGER/TRUCK            NaN
# 23   MULTI-UNIT DWELLING (APARTMENT, DUPLEX, ETC)          400.0
# 27                                         STREET          511.0
# 29                                       SIDEWALK            NaN
# 32                                       DRIVEWAY            NaN
# 33                                         STREET            NaN
# 37                                         STREET            NaN
# 40                                    PARKING LOT            NaN
# 110                                        STREET            NaN
#
#                                         Weapon Desc  Status   Status Desc  \
# 0                                               NaN      IC   Invest Cont
# 1                                               NaN      IC   Invest Cont
# 2                                          CLUB/BAT      IC   Invest Cont
# 3    STRONG-ARM (HANDS, FIST, FEET OR BODILY FORCE)      IC   Invest Cont
# 4                                     VERBAL THREAT      IC   Invest Cont
# 6                                               NaN      IC   Invest Cont
# 9                                               NaN      IC   Invest Cont
# 10                                              NaN      IC   Invest Cont
# 11                                              NaN      AO   Adult Other
# 14                                              NaN      IC   Invest Cont
# 15                                              NaN      AO   Adult Other
# 16                                              NaN      IC   Invest Cont
# 18                                              NaN      IC   Invest Cont
# 23   STRONG-ARM (HANDS, FIST, FEET OR BODILY FORCE)      AA  Adult Arrest
# 27                                    VERBAL THREAT      AO   Adult Other
# 29                                              NaN      IC   Invest Cont
# 32                                              NaN      IC   Invest Cont
# 33                                              NaN      IC   Invest Cont
# 37                                              NaN      IC   Invest Cont
# 40                                              NaN      IC   Invest Cont
# 110                                             NaN      IC   Invest Cont
#
#                                      LOCATION  \
# 0     1500    BEVERWIL                     DR
# 1     1700 W  45TH                         ST
# 2     1300 S  SOTO                         ST
# 3     2800    MONTCALM                     AV
# 4     2700    OBAMA                        BL
# 6     1300 N  SYCAMORE                     AV
# 9     8000    BROADLEAF                    AV
# 10   16800    VANOWEN                      ST
# 11    5300    MARMION                      WY
# 14            104TH                        ST
# 15   13100    COURBET                      LN
# 16     200 S  NORMANDIE                    AV
# 18     100 N  BEAUDRY                      AV
# 23     700    FIGUEROA                     PL
# 27            SUNSET                       AV
# 29            MARTHA                       ST
# 32   12700    DAVENTRY                     ST
# 33    1700 E  16TH                         ST
# 37    1500    2ND                          AV
# 40     800    SANTEE                       ST
# 110   7600    OSO                          AV
#
#                         Cross Street      LAT       LON  Cases per area
# 0                                NaN  34.0524 -118.3986            9214
# 1                                NaN  34.0028 -118.3089          141714
# 2                                NaN  34.0263 -118.2196            8339
# 3                                NaN  34.1223 -118.3563           11070
# 4                                NaN  34.0222 -118.3227           13468
# 6                                NaN  34.0944 -118.3428           11138
# 9                                NaN  34.2164 -118.4381            9117
# 10                               NaN  34.1939 -118.4989            8651
# 11                               NaN  34.1080 -118.1990            9629
# 14                          FIGUEROA  33.9419 -118.2826           11700
# 15                               NaN  34.3074 -118.5053            8961
# 16                               NaN  34.0712 -118.3004           10199
# 18                               NaN  34.0591 -118.2542            9500
# 23                               NaN  33.7781 -118.2808            8677
# 27   3RD                          AV  33.9960 -118.4735           12230
# 29   KESTER                       AV  34.1731 -118.4574            9549
# 32                               NaN  34.2850 -118.4090            7579
# 33                               NaN  34.0233 -118.2424           10720
# 37                               NaN  34.0455 -118.3189           10409
# 40                               NaN  34.0413 -118.2517           13561
# 110                              NaN  34.2083 -118.5754            9638
#
# [21 rows x 22 columns]

# %%
# Configure gmaps
gmaps.configure(api_key = "AIzaSyAt_EOD_wTikFHLRpiIbXXHi6TAUCduZAg")

# %%
# Store 'Lat' and 'Lng' into  locations 
locations = unique_areas[["LAT", "LON"]].astype(float)

# Convert Humidity Rate to float and store
cases = unique_areas['Cases per area'].astype(float)

# %%
# Create a humidity Heatmap layer
fig = gmaps.figure()

heat_layer = gmaps.heatmap_layer(locations, weights=cases, 
                                 dissipating=False, max_intensity=0.8,
                                 point_radius = 0.05)

fig.add_layer(heat_layer)

fig
# Out:
# Figure(layout=FigureLayout(height='420px'))

# %%
# for area in unique_areas:
# for idx,row in unique_areas.iterrows():
#     area = row["LOCATION"]
#     unique_areas.loc[idx,"LOCATION"]=new_crime_2019["AREA NAME"].value_counts()
